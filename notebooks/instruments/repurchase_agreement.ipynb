# %% [markdown]
# <center><img src="../../images/logo.png" alt="Your Image" style="width: 500px; height: auto"></center>
# <div>
#     <h1>Repurchase Agreement</h1>
# </div>

# %% [markdown]
# ## Basic Idea
#
# Repurchase Agreements (*repos*) can be viewed as a collateralized loan. Generally, the borrower (*seller*) agrees to sell an asset to the lender (*buyer*) for a specific amount of cash. The seller also agrees to buy the sold asset back at expiry of the contract for a larger amount of cash. The price for which the asset is sold is called the *purchase price*, while the price at which the asset is bought back is called *repurchase price*. Effectively, the seller borrowed collateralized cash from the buyer. The interest rate (*repo rate*) paid for the borrowed cash is implicit in the repurchase price and is quoted as a percentage per annum rate.
#
# From the perspective of the buyer, the transaction described above is called a *reverse repo*.
#
# The following image ([1]) illustrates the basic life cycle of a (reverse) repo transaction.

# %% [markdown]
# ![Repo schema](../images/repurchase_agreement/repo_schema.png)

# %% [markdown]
# ## The Repo Market
#
# ### Economic Functions
# The repo market plays a key role in facilitating the flow of cash and securities in the financial system. Additionally, repos and reverse repos are often carried out by central banks in order to temporarily provide liquidity to (or remove liquidity from) the financial system to support implementation of monetary policies and to promote financial stability.
#
# A few economic functions of the repo market are ([1,2]):
#
# 1. **Providing a low-risk option for cash investment & an efficient source of short term funding:**\
# High-quality liquid assets (HQLA) collateralized repos and reverse repos are commonly used by various market participants, including money market funds, banks, and other financial institutions, due to their ability to reduce credit and liquidity risks. Repos provide a secure and liquid investment option. Institutional investors also utilize repo contracts to address short-term liquidity needs without the need to liquidate long-term strategic investments.
#
# 2. **Facilitating central bank operations:**\
# As briefly noted at the beginning of this section, repos are a widely used tool in central bank open market operations. Collateralization helps to reduce the central bank's credit risk. In normal market conditions, the repo market allows central banks to implement monetary policies more effectively.
#
# 3. **Financing leverage investors and covering short positions:**\
# Institutional investors, such as hedge funds, utilize the repo market to borrow cash for financing leveraged investment strategies and to borrow securities for covering short positions. These funds play an important role in feeding market liquidity and price efficiency of underlying cash markets through trading and exploitation of pricing discrepancies (arbitrage).
#
# ### The Size of the European Repo Market
# The International Capital Market Accociation (ICMA) conducted an European repo market surveys in June of 2022 [3]. In this survey the ICMA asked financial institutions operating in Europe for the value of the cash side of (reverse) repos that were still outstanding at close of business on June 8th 2022. According to the ICMA survey, the total value of the repo contracts outstanding on the books of the 56 participated institutions was at 9,680 Billion EUR. The ICMA conducted prior a similar survey with 59 participants one year earlier, where the total value of outstanding repo transactions was at 8,726 Billion EUR [4].
#
# ### Typical Terms for Repos
# The market survey in [3] also compared the different maturities for repos between the financial institutions participated in the survey (main survey), automatic repo trading systems (ATS) and tri-party agents (which will be discussed later).
#
# ![Repo maturities](../images/repurchase_agreement/repo_maturities.png)
#
# ## Different Types of Collateral
# The quality of the underlying collateral of a repo is a key factor in determining the repo rate. Hence, repos backed by HQLAs typically have lower repo rates than repos backed by non HQLAs. While government bonds are the most commonly used collateral, equities and corporate bonds are also frequently utilized.
#
# Generally, assets provided as collateral in a repo contract can be classified as general collateral (GC) or special/specific collateral (SC). These two categories reflect the primary motivations behind repo transactions: *cash-driven* and *security-driven* repo transactions [1,6].
#
# ### General Collateral
# General collateral is a set or basket of securities which trade in the repo market at the same or a very similar repo rate (GC repo rate). This means that GC securities can be substituted for one another. Hence, the buyer in a GC repo is indifferent to which security is given as collateral. Due to the fact that securities can be substituted for one another, the driver of the GC repo rate is not the supply and demand of particular issues of securities, but of cash. Furthermore, a buyer in a repo may grant the seller permission to substitute some or all collateral during the term of the transaction [5]. General collateral repos are *cash-driven* repos as the underlying collateral plays a subordinate role. Cash-driven repos are primarily used for funding [1,6].
#
# ### Special Collateral
# While in GC repos the specific asset demanded as collateral is not important, as long as it comes from a specific GC basket, the specification of a certain asset privoded as collateral in SC repos is very much so. A special is an issue of securities that is subject to exceptional demand in the repo and cash markets compared to similar issues. A security is said to be *on special* (a special collateral) if the repo rate for that collateral is distinctly lower than the GC repo rate. The demand for some specials can become so large, that the special repo rate becomes negative [1,7]. The repo spread, which is the difference between the GC repo rate and the SC repo rate, can be seen as an implicit borrowing fee for the security on special. Thus, the lower repo rate for specials can be understood as the GC repo rate paid for the cash reduced by the borrowing fee for the security in high demand. Since the main intention of special repos is the borrowing of sought after securities, these repos are security-driven repos. One of the most common reasons for an security to go special is when that security becomes the *cheapest-to-deliver* in the futures market.
#
# ## Risks
# Generally, there are two sources of risk in repos, collateral and counterparty risk. The primary driver for counterparty risk is the credit risk, meaning the counterpartys inability to repay a loan or meet a contractual obligation. Counterparties with a higher credit risk also pay higher repo rates as compensation for the risk. The collateral risk consists of the liquidity risk, the volatility of the collateral's market price and the collateral's credit risk, which influence the quality of the collateral. The liqudity risk plays an important role in the event of the sellers default, since collateral taken from a risky counterparty is more likely to be liquidated to mitigate the buyers (cash lenders) losses, than collateral take from a non risky counterparty [1]. Additionally, repos with a longer time to maturity also have a higher repo rate. Further descriptions of best practices in cases of counterparty default will be provided in the next section. If the credit risk of the assets provided as collateral has a certain correlation to the credit risk of the party providing this asset, the collateral also has a *wrong-way risk*. In order to account for the collateral risk in repo transactions, so called *haircuts* or *initial margins* are included. The inital margin or haircut is a risk adjustment of the current market price of the collateral [1,8-10]. In other words, haircuts/initial marigns are an adjustment to the quoted market value of a collateral in order to account for the unexpected loss that the buyer may face due to the difficulty of selling the security in response to a seller's default. Thus, using a haircut $h$ or an initial margin $IM$, the purchase and repurchase price for a repo with repo rate $r$ and maturity in years $T$ can be calculated as follows:
#
# **Using a haircut**
#
# \begin{align*}
# P_\text{purchase} &= P_\text{market}\cdot(1-\frac{h}{100})\\
# P_\text{repurchase} &= P_\text{purchase}\cdot\left(1+r\cdot T\right)\\
# h &= \left(\frac{P_\text{market}-P_\text{purchase}}{P_\text{market}}\right)\cdot 100
# \end{align*}
#
# Thus, the haircut is expressed as the percentage difference between the market value of the collateral and the pruchase price of the repo.
#
# **Using an initial margin**
#
# \begin{align*}
# P_\text{purchase} &= \frac{P_\text{market}\cdot100}{IM}\\
# P_\text{repurchase} &= P_\text{purchase}\cdot\left(1+r\cdot T\right)\\
# IM &= \frac{P_\text{market}}{P_\text{purchase}}\cdot 100
# \end{align*}
#
# The initial margin is expressed as a relative to 100%. Thereby, an initial margin of 100% means no margin is applied.
# An initial margin of 102% is not equivalent to a haircut of 2%. The relationship between the haircut and the initial margin can be derived using the assumption that there exists an equilibrium where the haircut and the initial margin result in the same purchase price:
#
# \begin{align*}
# P_\text{market}\cdot(1-\frac{h}{100}) &= \frac{P_\text{market}\cdot100}{IM}\\
# 1-\frac{h}{100} &=\frac{100}{IM}\\
# \frac{100}{1-\frac{h}{100}} &=IM
# \end{align*}
#
# Thus, a haircut of 2% is equivalent to an initial margin of 102.041% [5,8,10-12]. The ICMA recommends that once the initial margin or haircut is agreed upon, the initial margin or haircut should be fixed for the full term of the repo [5].
#
# It is quite natural, that the market value of the collateral increases or decreases during the term of the repo. In cases where the market value decreases significantlly (more than the haircut accounts for) the buyer of the repo is exposed to the default of the seller, since the buyer may not be able to recover the money 'lend' by selling the collateral. Hence, the lender will call for variation margin to rebalance cash and collateral.
#
# *<u>Example</u>*\
# Consider a repo contract with collateral consisting of $M=100,000$ bonds, each with a dirty price $P_D=100$ €, giving a total nominal value of $N=10,000,000$ €. The repo rate is $3\%$ p.a., the haircut is $2\%$ and the term is one year.
#
# The purchase price is $P_\text{purchase}=9,800,000$ € and the repurchase price is $P_\text{repurchase}=10,094,000$.
#
# After 30 days, the dirty price of the collaterilzed bonds decreased to $P_{D,\text{30d}}=80$ €. At this point, interest has accrued on the purchase price for 30 days, making the current repurchase price $P_{\text{repurchase},30d}=9,824,164.38$ €. Since this repurchase price still includes the haircut, dividing it by $(1-\frac{h}{100})$ gives the corresponding market value of the collateral $P_{\text{market},30d}=10,024,658$.
#
# The actual market value of the collateral based on the dirty price is $P'_{\text{market},30d}=8,000,000$. Since $P_{\text{market},30d}$ exceeds $P'_{\text{market},30d}$, the seller must provider additional collateral to balance the values.
#
# The updated amount of collateral required can be calculated as $M' = P_{\text{market},30d}/P_{D,\text{30d}}=125,308$. Therefore, the seller needs to provide an additional $25,308$ bonds to meet the collateral requirement.
#
# The example above demonstrated a possible scenario, where the buyer of a repo is exposed to the default of the seller of a repo, once the market value of a collateral significantly decreases. In such cases the buyer will call for variational margin such that the exposure of the buyer is minimised. Additionally, both parties agree on a minimum exposure below which they will not call a margin. Each party's exposure is conducted daily [5,10,11].
#
# ## Collateral - Coupons and Dividends
# During the life of a repo, the buyer holds legal title to the collateral. This means that all payments produced by the security are paid by the issuer directly to the buyer. However, the seller of the collateral retains the risk on the collateral, as the seller has committed to buy the collateral back in the future for its original value plus repo interest. A key principle in the operation of repos is that only the seller should be exposed to the risks of the collateral. Hence, the seller will expect to receive the corresponding return. So, the buyer agrees to immediately pay compensatory amounts to the seller equivalent to any income payment received on the collateral (*manufactured payments*) [1,8,14].
#
# ## Collateral - Voting Rights
# Since the buyer holds legal title to the collateral, he/she is entitled to any benefits of ownership such as voting rights. The buyer can use this voting right to vote in accordance with the seller, but the buyer is not obligated to do so. However, according to the Equities Annex of the ICMA's Global Master Repurchase Agreement (GMRA), the right to take decisions on corporate actions in the case of equity being used as collateral is the seller's, provided that the seller gives the buyer requisite notice of the decision [1,14].
#
# ## Different Types of Repos
# ### Tri-party Repos
# Tri-party repos are repos for which collateral selection, payments and deliveries, custody of collateral securities, collateral management and other operations during the life of the transaction are outsourced by the parties to a third-party agent. Such a tri-party agent can be a custodian bank, an international central securities depository or a national central securities depository. In Europe, the principle tri-party agents are Clearstream Bank Luxembourg, Euroclear Bank and JP Morgan. Once a transaction has been agreed directly between the parties (usually by phone or electronic messaging) both parties independently notify the tri-party agent. The agent will automatically select, from the securities account of the seller, sufficient collateral. The tri-party agent manages the regular revaluation of the collateral, variation margining, income payments on the collateral and the substitution of collateral [1,10,15].
#
# ### Open Repos
# In an open repo (also called on demand or open-ended repo) the transactions is agreed without a fixed maturity date. This allows either party to terminate the repo on any business day, provided they give notice within an agreed-upon timeframe. Typically, the repo rate in an open repo can be adjusted (*re-rated*) upon the request of one party, but only with the agreement of the other. Alternatively, the repo rate can be tied to a one-day interest rate index, causing it to adjust automatically. These two methods can also be combined by quoting the repo rate as a floating rate plus or minus a spread, which either party can request to modify [1,10,16].
#
# Practitioners often use basis points (BP) to refer to interest rates or spreads, where $1BP=0.01\%$.
# Repo interest accrues daily without compounding. The accrued interest can be paid either on the repurchase date (as is common), on the re-rate date as a separate payment, or monthly as a discrete payment.
#
# ### Securities Lending
# Securities lendings and repos have many similarities. In a securities lending transaction one part gives legal title to a security or a basket of securities to another party, in exchange for legal ownership of collateral. The *seller* in a repo is the *lender* in the securities lending and the *buyer* is called *borrower*. The borrower pays a fee to the lender for the usage of the loaned security. The collateral in securities lending can either be cash or other securities. When cash is used as collateral, the arrangement resembles security-driven repos. In this case, the lender is obliged to reinvest the cash and rebate an agreed proportion of the reinvestment return back to the borrower. Thus, the equivalent of the repo rate in securities lending is known as the *rebate rate* [1]. Essentially, the lender who receives cash must pay interest on it, while the borrower pays a fee for the borrowed security, and the net effect of these two cash flows determines the rebate rate.
#
#
#
# ## Sources:
# [[1] Repo-FAQs-January-2019](https://www.icmagroup.org/assets/documents/Regulatory/Repo/Repo-FAQs-January-2019.pdf)\
# [[2] Repo market functioning](https://www.bis.org/publ/cgfs59.pdf)\
# [[3] European Repo Market Survey June 2022](https://www.icmagroup.org/assets/9789-ICMA-Repo-Survey-June-2022.pdf)\
# [[4] European Repo Market Survey June 2021](https://www.icmagroup.org/News/news-in-brief/the-european-repo-market-in-2021-icma-publishes-survey-showing-outstandings-of-eur-8726-billion-at-half-year/)\
# [[5] A Guide to Best Practive in the European Repo Market](https://www.icmagroup.org/assets/ERCC-Guide-to-Best-Practice-March-2022.pdf)\
# [[6] The EU Repo Markets: The Need For Full Integration](https://www.ceps.eu/wp-content/uploads/2015/03/RRinFBRepoMarkets.pdf)\
# [[7] Special Repo Rates: An Introduction](https://www.atlantafed.org/-/media/documents/research/publications/economic-review/2002/vol87no2_fisher.pdf)\
# [[8] Market Instruments for Collateral Management](https://www.iasonltd.com/doc/rps/2019/2019_Market_Instruments_for_Collateral_Management%20(Rev).pdf)\
# [[9] Collateral Value Risk in the Repo Market](https://faculty.fuqua.duke.edu/seminarscalendar/Smith_S13.pdf)\
# [[10] ICMA European Repo Council (ERC) Repo Margining Best Practices 2012](https://www.icmagroup.org/assets/documents/Regulatory/Repo/ICMA-ERC-Repo-Margining-Best-Practices-2012-(amended-7-Nov-2013)2.pdf)\
# [[11] Haircuts and initial margins in the repo market](https://www.icmagroup.org/assets/documents/Maket-Practice/Regulatory-Policy/Repo-Markets/Haircuts%20and%20initial%20margins%20in%20the%20repo%20market_8%20Feb%202012.pdf)\
# [[12] nature of repo](https://www.treasury.gov.ph/wp-content/uploads/2018/01/2-repo-risk-management-HO.pdf)\
# [[13] A Theory of Repurchase Agreements, Collateral Re-use, and Repo Intermediation](https://econ.wisc.edu/wp-content/uploads/sites/89/2018/09/Gottardi.pdf)\
# [[14] Global Master Repurchase Agreement](https://www.icmagroup.org/assets/documents/Legal/GMRA-2011_2011.04.20_formular_copy-incl-annexes-and-buy-sell-back-annex.pdf)\
# [[15] Security Market: an Overview of Repo and Security Lending Transactions](https://www.iasonltd.com/doc/rps/2019/2019_Security_Market-_an_Overview_of_Repo_and_Security_Lending_Transactions.pdf)\
# [[16] Floating-rate repo conventions](https://www.icmagroup.org/assets/documents/Regulatory/Repo/floating-rate-repo-convention---July-2012.pdf)
